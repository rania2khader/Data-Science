# %% [markdown]
# <a href="https://colab.research.google.com/github/rania2khader/Data-Science/blob/main/Copy_of_cartoon_effect_cat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files

# %%
def read_file(filename):
  img = cv2.imread(filename)
  cv2_imshow(img)
  return img

# %%
def color_quantization(img, k):
# Transform the image
  data = np.float32(img).reshape((-1, 3))

# Determine criteria
  criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 20, 0.001)

# Implementing K-Means
  ret, label, center = cv2.kmeans(data, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
  center = np.uint8(center)
  result = center[label.flatten()]
  result = result.reshape(img.shape)
  return result

# %%
def edge_mask(img, line_size, blur_value):
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  gray_blur = cv2.medianBlur(gray, blur_value)
  edges = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, line_size, blur_value)
  return edges

# %% [markdown]
# **Upload Image File**

# %%
uploaded = files.upload()

filename = next(iter(uploaded))
img = read_file(filename)
# Out:
#      <input type="file" id="files-d04d5111-7959-4629-8f38-5ad262a21b55" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d04d5111-7959-4629-8f38-5ad262a21b55">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 318111_314318451985856_25563897_n.jpg to 318111_314318451985856_25563897_n.jpg
# <PIL.Image.Image image mode=RGB size=500x317 at 0x7FEA0096B2D0>

# %% [markdown]
# **Run Code to Create Cartoon Effect**

# %%
line_size = 7
blur_value = 7

edges = edge_mask(img, line_size, blur_value)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=500x317 at 0x7FE9F3C94A10>

# %%
total_color = 5

img = color_quantization(img, total_color)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x317 at 0x7FE9F3C94C90>

# %%
blurred = cv2.bilateralFilter(img, d=7, sigmaColor=200,sigmaSpace=200)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=RGB size=500x317 at 0x7FE9F3C9AF10>

# %%
cartoon = cv2.bitwise_and(blurred, blurred, mask=edges)
cv2_imshow(cartoon)
# Out:
# <PIL.Image.Image image mode=RGB size=500x317 at 0x7FE9F2C24C50>
